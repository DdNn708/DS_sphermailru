# %% [markdown]
# ### Визуальный анализ данных

# %%
import pandas as pd

# %%
dt = pd.read_csv('data/dt.csv')
dt
# Out:
#              ID_code  target  var_108
# 0            train_0       0  14.1104
# 1            train_1       0  13.9550
# 2            train_2       0  14.1963
# 3            train_3       0  14.3256
# 4            train_4       0  14.0837
# ...              ...     ...      ...
# 199995  train_199995       0  14.3787
# 199996  train_199996       0  14.2993
# 199997  train_199997       0  14.0837
# 199998  train_199998       0  14.2625
# 199999  train_199999       0  14.1260
#
# [200000 rows x 3 columns]

# %%
dt.describe()
# Out:
#               target        var_108
# count  200000.000000  200000.000000
# mean        0.100490      14.224435
# std         0.300653       0.171091
# min         0.000000      13.729000
# 25%         0.000000      14.098900
# 50%         0.000000      14.226600
# 75%         0.000000      14.361800
# max         1.000000      14.743000

# %%
dt['var_108'].hist(bins=100)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(212)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(122)
ax3 = fig.add_subplot(223)

# %%
from numpy.random import randn

# %%
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(221)
plt.hist(randn(100), bins=20, color='y', alpha=0.9)
ax2 = fig.add_subplot(122)
plt.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
ax3 = fig.add_subplot(223)
plt.plot(randn(100).cumsum(), 'k--')

# %%
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(122)
ax3 = fig.add_subplot(223)

plt.plot(randn(100).cumsum(), 'k--')
# Метод fig.add_subplot возвращает объект AxesSubplot, что позволяет рисовать в любом подграфике, вызывая методы этого объекта:
f = ax1.hist(randn(100), bins=20, color='y', alpha=0.9)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
f
# Out:
# (array([ 4.,  2.,  2.,  3.,  7.,  7.,  7.,  4., 12.,  7., 10.,  5., 11.,
#          5.,  6.,  3.,  2.,  2.,  0.,  1.]),
#  array([-2.18517905, -1.95580426, -1.72642946, -1.49705467, -1.26767987,
#         -1.03830507, -0.80893028, -0.57955548, -0.35018069, -0.12080589,
#          0.10856891,  0.3379437 ,  0.5673185 ,  0.79669329,  1.02606809,
#          1.25544289,  1.48481768,  1.71419248,  1.94356727,  2.17294207,
#          2.40231687]),
#  <a list of 20 Patch objects>)

# %%
plt.plot(randn(100).cumsum())

# %%
fig, axes = plt.subplots(2, 3)
fig.set_figheight(5)
fig.set_figwidth(15)

axes[0,0].scatter(np.arange(30), np.arange(30) + 3 * randn(30)) 
axes[1,1].bar(np.arange(10), randn(10))
# Out:
# <BarContainer object of 10 artists>

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10e815690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e8b1890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e8f20d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10e927890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e96a050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e99f850>]],
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
fig.set_figheight(5)
fig.set_figwidth(15)

for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='r', alpha=0.5)
# Достаточно популярный способ задания пустого пространства вокруг графиков
plt.subplots_adjust(wspace=0.0, hspace=0.0)
# plt.savefig('fig.png', dpi=400, bbox_inches='tight')

# %%
plt.rc('figure', figsize=(10,10))
font_options = {'family': 'monospace'}
plt.rc('font', **font_options)

# %% [markdown]
# ## Визуализация с помощью Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/openpowerlifting_sample.csv', sep=',')

# %%
df.head(2)
# Out:
#    Unnamed: 0                Name Sex Event   Equipment   Age AgeClass  \
# 0     1128283      Tionne Edwards   F   SBD  Single-ply   NaN      NaN
# 1     1357160  Angel Hernandez #1   M   SBD       Wraps  30.0    24-34
#
#   Division  BodyweightKg WeightClassKg  ...  McCulloch  Glossbrenner  \
# 0    Girls         50.89          51.9  ...     247.21        219.33
# 1      MOR        100.00           100  ...     357.54        343.62
#
#    IPFPoints  Tested  Country  Federation        Date  MeetCountry  MeetState  \
# 0     343.84     Yes      NaN      THSWPA  2019-01-19          USA         TX
# 1     514.89     NaN      NaN         UPA  2019-03-30          USA         NE
#
#                              MeetName
# 0                        FCA Lift Off
# 1  Big Iron Rick Hussey Memorial Meet
#
# [2 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 38 columns):
# Unnamed: 0         300000 non-null int64
# Name               300000 non-null object
# Sex                300000 non-null object
# Event              300000 non-null object
# Equipment          300000 non-null object
# Age                159454 non-null float64
# AgeClass           165724 non-null object
# Division           298243 non-null object
# BodyweightKg       296491 non-null float64
# WeightClassKg      297200 non-null object
# Squat1Kg           70789 non-null float64
# Squat2Kg           69951 non-null float64
# Squat3Kg           67915 non-null float64
# Squat4Kg           804 non-null float64
# Best3SquatKg       217122 non-null float64
# Bench1Kg           105203 non-null float64
# Bench2Kg           104004 non-null float64
# Bench3Kg           100772 non-null float64
# Bench4Kg           2093 non-null float64
# Best3BenchKg       268883 non-null float64
# Deadlift1Kg        76246 non-null float64
# Deadlift2Kg        74678 non-null float64
# Deadlift3Kg        71281 non-null float64
# Deadlift4Kg        1951 non-null float64
# Best3DeadliftKg    227808 non-null float64
# TotalKg            276832 non-null float64
# Place              300000 non-null object
# Wilks              274990 non-null float64
# McCulloch          274949 non-null float64
# Glossbrenner       274990 non-null float64
# IPFPoints          268384 non-null float64
# Tested             230458 non-null object
# Country            82042 non-null object
# Federation         300000 non-null object
# Date               300000 non-null object
# MeetCountry        300000 non-null object
# MeetState          198508 non-null object
# MeetName           300000 non-null object
# dtypes: float64(22), int64(1), object(15)
# memory usage: 87.0+ MB

# %%
cols = ['Equipment', 'Age', 'BodyweightKg', 'WeightClassKg', 'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg', 'Place', 'TotalKg', 'Sex']
df = df[cols]
df.head()
# Out:
#     Equipment   Age  BodyweightKg WeightClassKg  Best3SquatKg  Best3BenchKg  \
# 0  Single-ply   NaN         50.89          51.9         77.11         38.56
# 1       Wraps  30.0        100.00           100        240.00        115.00
# 2  Single-ply  40.5         67.44          67.5        240.00        160.00
# 3  Single-ply   NaN         50.98          51.7        131.54         54.43
# 4  Single-ply   NaN         63.68          67.3        113.40         61.23
#
#    Best3DeadliftKg Place  TotalKg Sex
# 0            79.38     3   195.04   F
# 1           232.50     5   587.49   M
# 2           295.00     8   695.00   M
# 3           120.20     2   306.17   M
# 4           108.86     8   283.50   F

# %%
fig = plt.figure(figsize=(14,5))
df['Equipment'].value_counts().plot.bar()

# %%
fig = plt.figure(figsize=(14, 5))
df['Equipment'].value_counts().sort_index().plot.bar()

# %%
fig = plt.figure(figsize=(14,5))
(df['Equipment'].value_counts() / len(df)).plot.bar()

# %%
df.groupby(['Equipment'])[['BodyweightKg', 'TotalKg']].mean()
# Out:
#             BodyweightKg     TotalKg
# Equipment
# Multi-ply      95.247431  422.346442
# Raw            84.695944  341.341682
# Single-ply     82.284056  409.335634
# Straps         92.700000  343.750000
# Wraps          89.864156  523.933904

# %%
df.groupby(['Equipment'])[['BodyweightKg', 'TotalKg']].mean().plot.bar(figsize=(14,5), stacked = True)

# %%
fig = plt.figure(figsize= (14,5))
chart = df['Equipment'].value_counts().plot.line()
# plt.show()

# %%
fig = plt.figure(figsize= (14,5))
chart = df['Equipment'].value_counts().plot.area()

# %%
fig = plt.figure(figsize=(14,5))
df['Age'].plot.hist(bins=2)

# %%
df[df['Age']<50].sample(300).plot.scatter(x='BodyweightKg', y='Age', figsize=(14,5))

# %%
df[df['Age']<50].plot.scatter(x='BodyweightKg', y='Age', figsize=(14,5))

# %%
df[df['Age']<50].plot.hexbin(x='BodyweightKg', y='Age', figsize=(17,6), gridsize=25, cmap='Blues')

# %%
df.plot.hexbin(x='BodyweightKg', y='Age', figsize=(17,6), gridsize=25, cmap='Blues')

# %% [markdown]
# ## Визуализация с помощью Seaborn

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=(14,5))
sns.countplot(df['Equipment'])

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(221)
df['Age'].dropna().value_counts().sort_index().plot.line()
ax2 = fig.add_subplot(222)
sns.kdeplot(df.Age.dropna())

# %%
fig = plt.figure(figsize=(14,5))
sns.kdeplot(df.loc[:, ['BodyweightKg', 'Age']].dropna().sample(5000), color='r', cmap='Reds', shade=True, shade_lowest=False)
# Out:
# /Users/dnv/projects/ds_sphermailru/env/lib/python3.7/site-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
fig = plt.figure(figsize= (14,5))
sns.distplot(df['Age'].dropna(), kde=True)

# %%
sns.jointplot(x='BodyweightKg', y='Age', data=df, kind='hex', gridsize=20)

# %%
fig = plt.figure(figsize= (10,10))
sns.boxplot(y='Age', x='BodyweightKg', data=df[df.Age.isin(np.arange(20,40,1))], orient='h')

# %%
fig = plt.figure(figsize= (14,5))
sns.violinplot(y='TotalKg', x='Equipment', hue='Sex', split=True, data=df)

# %%
fig = plt.figure(figsize= (20,20))
cols = ['Age', 'BodyweightKg', 'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg', 'TotalKg']
sns_plot = sns.pairplot(df[cols].dropna().sample(30000))
sns_plot

# %%
df[cols].dropna().corr()
# Out:
#                       Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# Age              1.000000      0.137146      0.016736      0.079798
# BodyweightKg     0.137146      1.000000      0.634066      0.656680
# Best3SquatKg     0.016736      0.634066      1.000000      0.904691
# Best3BenchKg     0.079798      0.656680      0.904691      1.000000
# Best3DeadliftKg  0.044825      0.636630      0.904106      0.869660
# TotalKg          0.045370      0.664833      0.975891      0.953419
#
#                  Best3DeadliftKg   TotalKg
# Age                     0.044825  0.045370
# BodyweightKg            0.636630  0.664833
# Best3SquatKg            0.904106  0.975891
# Best3BenchKg            0.869660  0.953419
# Best3DeadliftKg         1.000000  0.960676
# TotalKg                 0.960676  1.000000

# %%
fig = plt.figure(figsize=(14,5))
sns.heatmap(df[cols].dropna().corr(), cmap='Blues')
